# %%
print("Welcome to Data Engineering Module!")
# Out:
# Welcome to Data Engineering Module!

# %%
#Variables and Data types
age = 25 #int
pi = 3.14 #float
name = "Habeeb" #str
is_student = True #bool

# %%
print(f"Welcome to Data Engineering Module, my name is {name}, I am the Module leader, and I am {age} years old.")
# Out:
# Welcome to Data Engineering Module, my name is Habeeb, I am the Module leader, and I am 25 years old.

# %%
a = 10
b = 3
print(a+b, a**b, a//b)
# Out:
# 13 1000 3

# %%
text = "Data Engineering"
print(text.lower())
print(text [0:4])  #first word
print(text [::-1]) #reverse string through slicing
# Out:
# data engineering
# Data
# gnireenignE ataD

# %%
#Lists
fruits = ["apple", "banana", "cherry"]
print(fruits)
print(fruits[0]) #indexing
fruits.append("date") #add new item
print(fruits)

#Tuples (immutable sequences)
coordinates = (10.5, 20.3)
print(coordinates)

#Dictionaries (key-value pairs)
student = {"name": "Alice", "age": 25, "course": "Data Engineering"}
print(student["name"])
print(student.get("course"))

#Sets (unique, unordered collection)
unique_numbers = {1,2,2,3,4}
print(unique_numbers)
# Out:
# ['apple', 'banana', 'cherry']
# apple
# ['apple', 'banana', 'cherry', 'date']
# (10.5, 20.3)
# Alice
# Data Engineering
# {1, 2, 3, 4}

# %%
#Documentation

s = 'Hello, world.'
str(s)
str(1/7)

x = 10 * 3.25
y = 200 * 200
s = 'The value of x is ' + str(x) + ', and y is ' + str(y) + '...'
print(s)
# Out:
# The value of x is 32.5, and y is 40000...

# %%
import pandas as pd
pd.DataFrame({'A': [1,2,3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
text_to_replace = 'Data Engineering'
print(text_to_replace.replace('Engineering','Science'))
# Out:
# Data Science
